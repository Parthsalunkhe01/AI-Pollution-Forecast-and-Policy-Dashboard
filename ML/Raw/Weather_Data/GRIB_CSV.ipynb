# %%
import pandas as pd

# %%
# !pip install cfgrib xarray netCDF4 pandas eccodes
# Out:
# ...
#   Using cached pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 8.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ------------------- -------------------- 3.4/7.1 MB 15.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 17.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    --------------------------- ------------ 5.0/7.2 MB 23.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 20.3 MB/s eta 0:00:00
# ...
# Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# ...
#
#    ----- ---------------------------------- 1/8 [pycparser]
#    -------------------- ------------------- 4/8 [cffi]
#    ------------------------- -------------- 5/8 [xarray]
#    ------------------------- -------------- 5/8 [xarray]
# ...

# %%
import xarray as xr
import pandas as pd

# Replace with your grib file name
grib_file = "6b3674fc0eac35994f5ad5cd47321978.grib"

# Open using xarray + cfgrib
ds = xr.open_dataset(grib_file, engine="cfgrib")

# Convert to DataFrame
df = ds.to_dataframe().reset_index()

# Save to CSV
df.to_csv("era5_2023.csv", index=False)

print("Conversion complete. Saved as era5_2023.csv")
# Out:
# skipping variable: paramId==228 shortName='tp'
# Traceback (most recent call last):
#   File "b:\DataScienceBootCamp\Python\venv\Lib\site-packages\cfgrib\dataset.py", line 726, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "b:\DataScienceBootCamp\Python\venv\Lib\site-packages\cfgrib\dataset.py", line 642, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='time' value=Variable(dimensions=('time',), data=array([1672531200, 1672534800, 1672538400, ..., 1704056400, 1704060000,
#        1704063600])) new_value=Variable(dimensions=('time',), data=array([1672509600, 1672552800, 1672596000, 1672639200, 1672682400,
#        1672725600, 1672768800, 1672812000, 1672855200, 1672898400,
#        1672941600, 1672984800, 1673028000, 1673071200, 1673114400,
#        1673157600, 1673200800, 1673244000, 1673287200, 1673330400,
#        1673373600, 1673416800, 1673460000, 1673503200, 1673546400,
# ...
