# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\samru\OneDrive\Desktop\SIH_2025\AI-Pollution-Forecast-and-Policy-Dashboard\ML\Raw\Air_Quality_Data\AQI_daily_2023_Alipur_Delhi_DPCC_2023.xlsx")

# %%
df.head()
# Out:
#   Day  January  February  March  April    May  June   July  August  September  \
# 0   1    292.0     132.0  134.0  201.0   78.0  75.0   65.0   111.0      139.0
# 1   2      NaN     171.0  223.0  112.0   61.0  91.0   60.0    79.0      131.0
# 2   3    369.0     203.0  123.0  163.0   95.0  96.0   94.0    69.0      140.0
# 3   4    300.0     266.0  113.0   86.0  150.0   NaN  155.0    81.0      134.0
# 4   5    307.0     253.0  116.0  124.0  171.0   NaN   98.0    65.0       90.0
#
#    October  November  December
# 0    146.0     320.0     341.0
# 1    143.0     360.0     341.0
# 2    160.0     425.0     308.0
# 3    166.0     383.0     316.0
# 4    180.0     401.0     306.0

# %%
df
# Out:
#                   Day  January  February  March  April    May   June   July  \
# 0                   1    292.0     132.0  134.0  201.0   78.0   75.0   65.0
# 1                   2      NaN     171.0  223.0  112.0   61.0   91.0   60.0
# 2                   3    369.0     203.0  123.0  163.0   95.0   96.0   94.0
# 3                   4    300.0     266.0  113.0   86.0  150.0    NaN  155.0
# 4                   5    307.0     253.0  116.0  124.0  171.0    NaN   98.0
# 5                   6    360.0     298.0  128.0  156.0  220.0    NaN   57.0
# 6                   7    334.0     297.0  186.0  142.0  200.0  207.0   70.0
# 7                   8    326.0     119.0  211.0  153.0  123.0  145.0   60.0
# 8                   9    366.0     211.0   93.0  230.0  203.0  163.0    NaN
# 9                  10    357.0     277.0  174.0  223.0  210.0  137.0    NaN
# 10                 11    261.0     289.0  225.0  296.0  303.0  125.0   50.0
# ...

# %%
print("Missing values per column:")
print(df.isna().sum())
# Out:
# Missing values per column:
# Day          1
# January      0
# February     0
# March        0
# April        0
# May          0
# June         0
# July         0
# August       0
# September    0
# October      0
# November     0
# December     0
# dtype: int64

# %%
# Count duplicates first
duplicate_count = df.duplicated().sum()
print("Number of duplicate rows:", duplicate_count)

# Remove duplicates
df = df.drop_duplicates(keep="first").reset_index(drop=True)
print("Duplicates removed.")
# Out:
# Number of duplicate rows: 0
# Duplicates removed.

# %%
import numpy as np

df_out = df.copy()

for col in month_cols:
    Q1 = df_out[col].quantile(0.25)
    Q3 = df_out[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    median_val = df_out[col].median()

    # Replace outliers
    df_out[col] = np.where((df_out[col] < lower) | (df_out[col] > upper),
                           median_val,
                           df_out[col])

print("Outliers replaced using month-wise median.")
# Out:
# Outliers replaced using month-wise median.

# %%
df
# Out:
#                   Day     January   February       March       April  \
# 0                   1  292.000000  132.00000  134.000000  201.000000
# 1                   2  249.314286  171.00000  223.000000  112.000000
# 2                   3  369.000000  203.00000  123.000000  163.000000
# 3                   4  300.000000  266.00000  113.000000   86.000000
# 4                   5  307.000000  253.00000  116.000000  124.000000
# 5                   6  360.000000  298.00000  128.000000  156.000000
# 6                   7  334.000000  297.00000  186.000000  142.000000
# 7                   8  326.000000  119.00000  211.000000  153.000000
# 8                   9  366.000000  211.00000   93.000000  230.000000
# 9                  10  357.000000  277.00000  174.000000  223.000000
# 10                 11  261.000000  289.00000  225.000000  296.000000
# 11                 12  369.000000  161.00000  142.911765  220.000000
# 12                 13  378.000000  125.00000  257.000000  220.000000
# ...
